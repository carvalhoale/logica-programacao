# %% [markdown]
# #Visualização de Váriaveis e textos

# %%
print ("Conhecendo comando print")

x = 8
print(x)
# Out:
# conhecendoo comando print
# 8

# %%
y = 10
soma = x + y
print(soma)
# Out:
# 15

# %%
nome = "alessandro"
print(nome)
# Out:
# alessandro

# %% [markdown]
# #Concatenação

# %%
x = 5
print("O valor de x é", x)
# Out:
# O valor de x é 5

# %%
print ("O valor de x é", x, "e o dobro é", x * 2)
# Out:
# O valor de x é 5 e o dobro é 10

# %%
print("Eu,", nome, "tirei", x, "Na prova de Phyton")
# Out:
# Eu, alessandro tirei 5 Na prova de Phyton

# %%
y = 10; z = 20 + x - y
print("Declarar varia váriaveis na mesma linha", y,z)
# Out:
# Declarar varia váriaveis na mesma linha 10 15

# %% [markdown]
# #Type

# %%
x = 10
type(x)
print("x", type(x))

nome = "Alessandro"
print("nome", type(nome))

num = "100"
num_convert = int(num) #Converter váriavel
print("num", type(num))
print("num_conver", type(num_convert))

num_float = float(num)
print("num_float", num_float)
# Out:
# x <class 'int'>
# nome <class 'str'>
# num <class 'str'>
# num_conver <class 'int'>
# num_float 100.0

# %% [markdown]
# #Input
#
#
#
# *   Armazenar a informação digitada pelo usuário em uma variável
# *   O dado armazenamento seré um texto

# %%
nome = input("Difgite o nome do usuário ") #Aguardndi o usuário digitar algo
print(nome)
# Out:
# Difgite o nome do usuário alessandro
# alessandro

# %%
valor = input("digite a nota ")

print(nome, "Sua nota foi", valor)
# Out:
# digite a nota 10
# alessandro Sua nota foi 10

# %%
valor = input("Digite o valor do produto: ")
print(valor)
# Out:
# Digite o valor do produto: 100
# 100

# %%
desconto = valor - 5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4693ea9a50ed> in <cell line: 0>()
# ----> 1 desconto = valor - 5
#
# NameError: name 'valor' is not defined

# %%
valor_convert = int(valor)
desconto = valor_convert - 5
print(desconto)
# Out:
# 95

# %%
desconto = int(valor) -5
print(desconto)
# Out:
# 95
